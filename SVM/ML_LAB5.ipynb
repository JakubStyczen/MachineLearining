# %% [markdown]
# # SVM

# %% [markdown]
# ## Wprowadzenie do Maszyn Wektorów Nośnych

# %%
import pandas as pd
import numpy as np
 
from sklearn import svm
 
import matplotlib.pyplot as plt

# %%
n_cls = 20   # Number of samples in each class.
 
np.random.seed(1)  # for reproducibility
x11 = np.random.normal(0.5, 1, (n_cls, 1))
np.random.seed(2)  # for reproducibility
x12 = np.random.normal(0.4, 1, (n_cls, 1))
np.random.seed(3)  # for reproducibility
x21 = np.random.normal(-0.3, 1, (n_cls, 1))
np.random.seed(4)  # for reproducibility
x22 = np.random.normal(-0.5, 1, (n_cls, 1))
 
X = np.vstack((
    np.hstack((x11, x12)),
    np.hstack((x21, x22))
))
 
y = np.hstack((-1 * np.ones(n_cls), +1 * np.ones(n_cls)))

# %%
print(X.shape)
# Out:
# (40, 2)

# %%
clf = svm.SVC(kernel='linear', C=1000, random_state=1, probability=True)
clf.fit(X, y)
# Out:
# SVC(C=1000, kernel='linear', probability=True, random_state=1)

# %%
fig = plt.figure(1)
plt.clf()
 
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)
 
# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()
 
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)
 
# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 16
#      14 YY, XX = np.meshgrid(yy, xx)
#      15 xy = np.vstack([XX.ravel(), YY.ravel()]).T
# ---> 16 Z = clf.decision_function(xy).reshape(XX.shape)
#      18 # plot decision boundary and margins
#      19 ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
#      20            linestyles=['--', '-', '--'])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:779, in BaseSVC.decision_function(self, X)
#     752 def decision_function(self, X):
#     753     """Evaluate the decision function for the samples in X.
#     754
#     755     Parameters
#    (...)
#     777     transformation of ovo decision function.
#     778     """
# --> 779     dec = self._decision_function(X)
#     780     if self.decision_function_shape == "ovr" and len(self.classes_) > 2:
#     781         return _ovr_decision_function(dec < 0, -dec, len(self.classes_))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:529, in BaseLibSVM._decision_function(self, X)
#     515 """Evaluates the decision function for the samples in X.
#     516
#     517 Parameters
#    (...)
#     525     in the model.
#     526 """
#     527 # NOTE: _validate_for_predict contains check for is_fitted
#     528 # hence must be placed before any other attributes are used.
# --> 529 X = self._validate_for_predict(X)
#     530 X = self._compute_kernel(X)
#     532 if self._sparse:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\svm\_base.py:607, in BaseLibSVM._validate_for_predict(self, X)
#     604 check_is_fitted(self)
#     606 if not callable(self.kernel):
# --> 607     X = self._validate_data(
#     608         X,
#     609         accept_sparse="csr",
#     610         dtype=np.float64,
#     611         order="C",
#     612         accept_large_sparse=False,
#     613         reset=False,
#     614     )
#     616 if self._sparse and not sp.issparse(X):
#     617     X = sp.csr_matrix(X)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 2 features, but SVC is expecting 4 features as input.

# %%
X_new = np.array([[1, -0.4],
    [-1, -0.85],
    ])
 
y_new = clf.predict(X_new)
plt.scatter(X_new[:, 0], X_new[:, 1], c=y_new, s=100)
fig.canvas.draw()
fig.canvas.flush_events()

# %%
# Get posterior probabilities for predictions (requires SVC to be created with
#   `probability=True`).
post_probs = clf.predict_proba(X_new)
print(post_probs)
# Out:
# [[0.62901122 0.37098878]
#  [0.26314804 0.73685196]]

# %%
from sklearn.datasets import load_iris
 
data = load_iris()
X = data.data
y = data.target

# %%
clf = svm.SVC(kernel='linear', C=1000, random_state=1, probability=True)
clf.fit(X, y)
# Out:
# SVC(C=1000, kernel='linear', probability=True, random_state=1)
